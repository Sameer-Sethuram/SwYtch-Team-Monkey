# %% [markdown]
# so for now we're going to take all of the layoffs that Sameer organized in the .pkl file from earlier and then, using his instructions, process the data to properly model and predict the layoffs in the job market in first 3, then 6, then 9, then 12 month intervals

# %%
# Cell 1: Imports
import pickle
import pandas as pd  # You'll need this for loading CSVs later

# %%
loaded_data = load_pkl("C:\\git\\SwYtch-Team-Monkey\\Modeling\\Indeed Hiring Lab\\Layoff Modeling\\top_features_layoffs.pkl")

# %%
# Cell 2: Load the feature dictionaries
with open(r"C:\git\SwYtch-Team-Monkey\Modeling\Indeed Hiring Lab\Layoff Modeling\top_features_layoffs.pkl", "rb") as f:
    top_features_openings = pickle.load(f)

with open("top_features_dict_PCA.pkl", "rb") as f:
    top_features_layoffs = pickle.load(f)

# Cell 3: Check what you loaded
print("Openings features loaded:", type(top_features_openings))
print("Number of industries:", len(top_features_openings))
print("\nLayoffs features loaded:", type(top_features_layoffs))
print("Number of industries:", len(top_features_layoffs))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Cell 2: Load the feature dictionaries
# ----> 2 with open("top_features_dict_spearman.pkl", "rb") as f:
#       3     top_features_openings = pickle.load(f)
#       5 with open("top_features_dict_PCA.pkl", "rb") as f:
#
# File c:\git\SwYtch-Team-Monkey\.venv\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'top_features_dict_spearman.pkl'
